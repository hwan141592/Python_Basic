# %% [markdown]
# # Network

# %% [markdown]
# 프로토콜
#
# - 인터넷을 통해 데이터를 주고받을 때는 어떤 규약에 따라 데이터를 교환한다.
# - 이런 데이터 교환 과정에서의 규약을 프로토콜(protocol)이라 함.
# - Web은 HTTP 프로토콜에 따라 데이터를 주고 받고 있음.
#
# Terms
#
# - Communication(통신) : 데이터를 보내고 싶은 곳에 원격으로 전송하고 다시 데이터를 수신받는 것
# - HTTP : HyperText Transfer Protocol / 하이퍼텍스트 전송 프로토콜
# - Protocol : 통신 규약
# - HyperText : 독자가 즉시 엑세스할 수 있는 다른 텍스트에 대한 참조(하이퍼링크)가 있는 기계에 표시되는 텍스트.
# - HyperText는 문자열의 일종 / 인터넷에 표시도어 있는 텍스트를 의미.
#
# 요약
#
# - 우리는 웹을 통해서 데이터를 원격으로 주고 받음. 이 때 쓰이는 텍스트는 HyperText, 프로토콜은 HTTP.
#
# 인터넷
#
# - 컴퓨터들 사이의 TCP/IP (Transmission Control Protocol / Internet Protocol)이라는 통신 프로토콜을 이용해 정보를 주고 받는 네트워크.
# - 1995.10.24. 미국 연방네트워킹위원회(Federal Networking Council, FNC)
# - 인터넷의 정의
#
#     The Federal Networking Council (FNC) agrees that the following language reflects our definition of the term "Internet. "Internet refers to the global information system that – (i) is logically linked together by a globally unique address space based on the Internet Protocol (IP) or its subsequent extensions/follow-ons; (ii) is able to support communications using the Transmission Control Protocol/Internet Protocol (TCP/IP) suite or its subsequent extensions/follow-ons, and/or other IP-compatible protocols; and (iii) provides, uses or makes accessible, either publicly or privately, high level services layered on the communications and related infrastructure described herein.
#
# - 인터넷 프로토콜(Internet Protocol, IP) 또는 IP의 확장이나 후속 프로토콜에 기반을 두고 글로벌하게 접속 가능하며, 단일 주소공간에 의해 논리적으로 연결.
# - TCP/IP 프로토콜, 이것의 확장이나 후속 프로토콜, 그리고 다른 IP와 호환되는 프로토콜을 이용한 통신을 지원할 수 있어야 한다.
# - 위에 언급한 인프라 구조나 통신 계층 위의 공공 또는 사적으로 고수준의 서비스를 제공하거나 사용, 접근이 가능하다.
#
# -> 한 마디로, 인터넷은 TCP/IP 프로토콜에 의해 데이터의 교환이 가능한 글로벌 정보시스템을 일컫는다.
#
# ## 소켓 통신
#
# - 소켓 : 인터넷 연결용 포트
# - 인터넷 소켓 (or 네트워크 소켓) : Endpoint를 의미.
#     ->  endpoint : 전송이 되거나 혹은 전달받는 지점
# - 데이터를 전달하고 전송하는 지점을 뜻하기도 하고 전체 행위를 나타내기도 함.
# - 소켓과 소켓 사이의 peer-to-peer 연결을 구현하는 프로토콜 : TCP
# - SW는 이 소켓을 가지고 있기 때문에 반대편으로부터 전송받은 데이터를 바로 이 소켓을 통해서 수신하게 됨.
#
# - 소켓에는 번호가 붙어 있고, 이를 포트번호(port)라고 함.
# - e.g.) 웹브라우저가 웹서버에 접속할 때는 웹서버의 80번 포트에 접속하는 것이 관례적으로 약속되어 있음.
# -> HTTP 프로토콜의 서비스를 제공하는 포트를 80으로 삼은 것
# - port number e.g.) 관례적으로, FTP : 21번 / SSH : 22번 / telnet : 23번
#
# ## TCP/IP
#
# **TCP/IP**
#
# - 인터넷 상에서 데이터를 교환할 때 쓰이는 프로토콜 (TCP, IP 2개)
#     - TCP : Transmission Control Protocol / 소켓 포트 단위의 송수신 프로토콜
#     - IP : Internet Protocol / 컴퓨터마다 주어지는 IP 주소 단위의 송수신 프로토콜
# - 차이
#     - TCP : 포트번호 단위 통신 & 프로그램 level 통신 프로토콜
#     - IP : IP 주소 단위 통신 & 컴퓨터 level 통신 프로토콜
# - IP를 통해 데이터가 특정 컴퓨터까지 전달되고, 포트번호를 따라 정확하게 소켓까지 전달해주는 것은 TCP의 역할.
#
# **참고**
#
# - UDP : User Datagram Protocol
#     - TCP : 두 소켓간의 쌍방향 독점적 통신. connection 기반의 통신 프로토콜
#     - UDP : connection 개념이 없는 비연결형. 데이터그램을 일방적으로 전송하기 때문에 전송속도는 TCP보다 빠름. 음성, 영상 데이터 전송에 유리.
#
# TCP/IP
#
# - functionally 4 layers
#     - Application Layer : 애플리케이션에 표준화된 데이터 교환을 제공. HTTP, FTP, SMTP, SNMP
#     - Transport Layer : end-to-end 커뮤니케이션 유지
#     - Network Layer : IP를 이용해서 패킷을 운영하고 네트워크를 연결
#     - Physical Layer
#
# # Web & HTTP
#
# - 웹의 문서와 프로토콜, 식별 규칙
#     - 표현형식(문서) : HTML(Hyper Text Markup Language)
#     - 전송방법(프로토콜) : HTTP (Hyper Text Transfer Protocol)
#     - 식별자(UR) : Uniform Resource Identifier
# - 웹은 통신 규약으로 HTTP를 사용
# - HTTP : 요청(Request)하고 응답(Response)하는 서버/클라이언트 모델을 따름.
#
# # HTTP 메시지
#
# - HTTP 메시지 = request / status line + header + body
# - Request Method (요청 메소드)
#     - GET : read 정보를 요청
#     - HEAD : 헤더 정보만 요청
#     - POST : create, 정보를 생성 및 변형할 때 사용
#     - DELETE : delete, 정보를 삭제
#     - OPTIONS : 사용 가능한 메소드 확인
#     - 그 외 : PATCH, CONNECT, TRACE
#     - 보통은 보안 문제로 인해 GET과 POST를 주로 사용함.
# - 응답 메시지는 status line에 상태코드(status code)를 포함함.
# - Response Code (응답코드)
#     - 1xx : 조건부 응답
#     - 2xx : 성공
#     - 3xx : 리다이렉션 완료
#     - 4xx : 요청 오류 ( 클라이언트에 문제가 있다는 뜻)
#     - 5xx : 서버 오류 (서버에 문제가 있다는 뜻)
# - 자주 사용하는 응답코드
#     - 200 : 서버가 클라이언트 요청을 성공적으로 처리. 웹페이지에서는 페이지 요청이 정상적으로 완료되면 반환
#     - 404 : 찾을 수 없음. 존재하지 않는 URL을 요청하여 페이지를 접속할 수 없을 때 반환하는 응답코드.
#
#     [HTTP 상태 코드](https://ko.wikipedia.org/wiki/HTTP_%EC%83%81%ED%83%9C_%EC%BD%94%EB%93%9C)
#
# **Header**
#
# - 헤더는 쓰임이 다양하고 종류가 많음.
# - 요청과 응답 메시지 모두에 사용되는 공통 헤더, 요청 메시지에서 사용되는 요청 헤더, 응답 메시지에 사용되는 응답 헤더가 있음.
#
# **URL (Uniform Resource Locator) 과 URI (Uniform Resource Identifier)**
#
# - 인터넷의 주소 체계 중 하나
# - 인터넷의 자원(resource)을 나타내는 식별자(identifier)이자 자원을 나타내는 주소.
# - URL
#     - 웹의 자원을 가리키는 위치 지정자
#     - 사실 URL은 URI에 포함되는 하위개념.
# - ex)
#     - [http://lms.aiffel.io/steps](http://lms.aiffel.io/steps/) : URI 이면서 URL
#     - [http://lms.aiffel.io/steps/828](http://lms.aiffel.io/steps/828) : URI (URL은 아님.)
#
# # API
#
# - Application Programing Interface
# - 다른 여러 애플리케이션 사이에 간편한 인터페이스를 제공.
# - API가 요청을 보낼 때는 HTTP를 통해 데이터를 요청하며 API는 이 데이터를 JSON이나 XML 형태로 반환.
# - 프로그램 간의 인터페이스(interface)
# - Request : 주소 / 전송방식(GET) / 정보:query, sort ...
# - Response : 형식(json, xml) / 의미설명(place:지역이름 / temp:기온)
#
# ## Rest API
#
# - HTTP 표준에 충실하게 설계된 API의 장점 : 어떤 언어, 어떤 플랫폼에서도 사용이 가능한 인터페이스 스타일이기 때문에 API 활용이 간결해짐.
# - Rest API는 이러한 HTTP기반 API의 장점을 극대화, HTTP 고유 특성을 가장 제대로 살린 디자인 패턴으로 인기.
# - Rest란?
#     - Representational State Transfer
#     - 자원을 URI로 표시하고 해당 자원의 상태를 주고받는 것을 의미.
#     - 구성요소
#         - 자원(Resource) : URI
#         - 행위(Verb) : HTTP Method
#         - 표현(Representations)
#         - Rest는 URI를 통해 자원을 표시하고, HTTP Method를 이용하여 해당 자원의 행위를 정해주며, 그 결과를 받는 것을 의미한다.
#     - Rest API는 Rest 기반의 규칙들을 지켜서 설계된 API를 말한다.
#     - Rest API 혹은 Restful API라고 함.
#
# [REST API와 RESTful API](https://velog.io/@stampid/REST-API%EC%99%80-RESTful-API#2-rest%EC%9D%98-%ED%8A%B9%EC%A7%95)
#
# - Rest API 설계 규칙
#
# api key
#
# 5223c6043aa3f290610378ff3d05b300

# %%
import requests
myapi = "af44a23b3fa31260fd92b236a65bffa3"

#lat: 위도, #lon:경도
def makeurl(lat, lng):
    url = "https://api.openweathermap.org/data/2.5/onecall?lat={}&lon={}&appid={}".format(lat, lng, myapi)
    return url

response = requests.get(makeurl(37,127))
weather = response.json()
weather
# Out:
# {'lat': 37,
#  'lon': 127,
#  'timezone': 'Asia/Seoul',
#  'timezone_offset': 32400,
#  'current': {'dt': 1604061319,
#   'sunrise': 1604008436,
#   'sunset': 1604047033,
#   'temp': 281.74,
#   'feels_like': 279,
#   'pressure': 1026,
#   'humidity': 53,
#   'dew_point': 272.76,
#   'uvi': 3.48,
#   'clouds': 1,
#   'visibility': 10000,
#   'wind_speed': 0.99,
#   'wind_deg': 122,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}]},
#  'minutely': [{'dt': 1604061360, 'precipitation': 0},
#   {'dt': 1604061420, 'precipitation': 0},
#   {'dt': 1604061480, 'precipitation': 0},
#   {'dt': 1604061540, 'precipitation': 0},
#   {'dt': 1604061600, 'precipitation': 0},
#   {'dt': 1604061660, 'precipitation': 0},
#   {'dt': 1604061720, 'precipitation': 0},
#   {'dt': 1604061780, 'precipitation': 0},
#   {'dt': 1604061840, 'precipitation': 0},
#   {'dt': 1604061900, 'precipitation': 0},
#   {'dt': 1604061960, 'precipitation': 0},
# ...

# %%
sys.version_info
# Out:
# sys.version_info(major=3, minor=8, micro=3, releaselevel='final', serial=0)

# %% [markdown]
# # XML Data Parcing

# %% [markdown]
# ### phase.1
#  - all steps

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import sys

if sys.version_info[0] == 3 : 
    from urllib.request import urlopen  
else : 
    from urllib import urlopen

# %%
url = "https://www.w3schools.com/xml/cd_catalog.xml"
url
# Out:
# 'https://www.w3schools.com/xml/cd_catalog.xml'

# %%
opened = urlopen(url)
opened

# %%
response = opened.read()
print("type of 'response' :", type(response))
response[0:200]
# Out:
# type of 'response' : <class 'bytes'>
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n<CATALOG>\r\n  <CD>\r\n    <TITLE>Empire Burlesque</TITLE>\r\n    <ARTIST>Bob Dylan</ARTIST>\r\n    <COUNTRY>USA</COUNTRY>\r\n    <COMPANY>Columbia</COMPANY>\r\n    <PRICE>'

# %%
response = urlopen(url).read()
print("type of 'response' :", type(response))
response[0:200]
# Out:
# type of 'response' : <class 'bytes'>
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n<CATALOG>\r\n  <CD>\r\n    <TITLE>Empire Burlesque</TITLE>\r\n    <ARTIST>Bob Dylan</ARTIST>\r\n    <COUNTRY>USA</COUNTRY>\r\n    <COMPANY>Columbia</COMPANY>\r\n    <PRICE>'

# %%
xtree = ET.fromstring(response)
xtree
# Out:
# <Element 'CATALOG' at 0x7fc0197cf1d0>

# %%
for node in xtree : 
    n_title = node.find("TITLE").text  # title : error
    print(n_title)
# Out:
# Empire Burlesque
# Hide your heart
# Greatest Hits
# Still got the blues
# Eros
# One night only
# Sylvias Mother
# Maggie May
# Romanza
# When a man loves a woman
# Black angel
# 1999 Grammy Nominees
# For the good times
# Big Willie style
# Tupelo Honey
# Soulsville
# The very best of
# Stop
# Bridge of Spies
# Private Dancer
# Midt om natten
# Pavarotti Gala Concert
# The dock of the bay
# Picture book
# Red
# Unchain my heart

# %%
rows = []

# iterate through each node of the tree
for node in xtree:
    n_title = node.find("TITLE").text
    n_artist = node.find("ARTIST").text
    n_country = node.find("COUNTRY").text
    n_company = node.find("COMPANY").text
    n_price = node.find("PRICE").text
    n_year = node.find("YEAR").text
    
    rows.append({"title": n_title, 
                 "artist": n_artist, 
                 "country": n_country, 
                 "company": n_company, 
                 "price": n_price, 
                 "year": n_year})

# %%
# convert XML data to pandas DataFrame

columns = ["title", "artist", "country", "company", "price", "year"]

catalog_cd_df = pd.DataFrame(rows, columns = columns)



catalog_cd_df.head(10)
# Out:
#                       title           artist country         company  price  \
# 0          Empire Burlesque        Bob Dylan     USA        Columbia  10.90
# 1           Hide your heart     Bonnie Tyler      UK     CBS Records   9.90
# 2             Greatest Hits     Dolly Parton     USA             RCA   9.90
# 3       Still got the blues       Gary Moore      UK  Virgin records  10.20
# 4                      Eros  Eros Ramazzotti      EU             BMG   9.90
# 5            One night only         Bee Gees      UK         Polydor  10.90
# 6            Sylvias Mother          Dr.Hook      UK             CBS   8.10
# 7                Maggie May      Rod Stewart      UK        Pickwick   8.50
# 8                   Romanza   Andrea Bocelli      EU         Polydor  10.80
# 9  When a man loves a woman     Percy Sledge     USA        Atlantic   8.70
#
#    year
# 0  1985
# 1  1988
# 2  1982
# 3  1990
# 4  1997
# 5  1998
# 6  1973
# 7  1990
# 8  1996
# 9  1987

# %%
catalog_cd_df.dtypes
# Out:
# title      object
# artist     object
# country    object
# company    object
# price      object
# year       object
# dtype: object

# %%
import numpy as np

catalog_cd_df = catalog_cd_df.astype({'price': np.float, 

                                      'year': int})

# %%
country_mean = catalog_cd_df.groupby('country').price.mean()

country_mean
# Out:
# country
# EU        9.320000
# Norway    7.900000
# UK        8.984615
# USA       9.385714
# Name: price, dtype: float64

# %%
country_mean_df = pd.DataFrame(country_mean).reset_index()



import seaborn as sns

sns.barplot(x='country', y='price', data=country_mean_df)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f83d480d1ab6> in <module>
#       7 sns.barplot(x='country', y='price', data=country_mean_df)
#       8
# ----> 9 plt.show()
#      10
#
# NameError: name 'plt' is not defined
